# %%
# Drop-out
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout,Input
from keras.utils import to_categorical
iris = load_iris()
X = iris.data
y = iris.target
y = to_categorical(y)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(y_train.shape[1], activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_data=(X_val, y_val))
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

#Early stopping
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
iris = load_iris()
X = iris.data
y = iris.target
y_class = to_categorical(y, num_classes=3)
y_regression = X[:, 2]
X_train, X_val, y_class_train, y_class_val, y_regression_train, y_regression_val = train_test_split(
    X, y_class, y_regression, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
input_layer = Input(shape=(X_train.shape[1],))
x = Dense(64, activation='relu')(input_layer)
x = Dropout(0.3)(x)
x = Dense(32, activation='relu')(x)
class_output = Dense(3, activation='softmax', name='class_output')(x)
reg_output = Dense(1, activation='linear', name='reg_output')(x)
model = Model(inputs=input_layer, outputs=[class_output, reg_output])
model.compile(optimizer=Adam(),
              loss={'class_output': 'categorical_crossentropy', 'reg_output': 'mse'},
              metrics={'class_output': 'accuracy', 'reg_output': 'mae'})
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train,
                    {'class_output': y_class_train, 'reg_output': y_regression_train},
                    epochs=10,
                    batch_size=10,
                    validation_data=(X_val, {'class_output': y_class_val, 'reg_output': y_regression_val}),
                    callbacks=[early_stopping])
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Total Loss (Classification + Regression)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()


#Gradient clipping
y = to_categorical(y)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(y_train.shape[1], activation='softmax'))
optimizer = Adam(clipvalue=1.0)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_data=(X_val, y_val))
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss with Gradient Clipping')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.3855 - loss: 1.0888 - val_accuracy: 0.6667 - val_loss: 0.8045
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5647 - loss: 0.9028 - val_accuracy: 0.6222 - val_loss: 0.6766
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5301 - loss: 0.7884 - val_accuracy: 0.7333 - val_loss: 0.5954
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7148 - loss: 0.6796 - val_accuracy: 0.8000 - val_loss: 0.5361
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8095 - loss: 0.6273 - val_accuracy: 0.8000 - val_loss: 0.4891
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7671 - loss: 0.5497 - val_accuracy: 0.8000 - val_loss: 0.4518
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8621 - loss: 0.5298 - val_accuracy: 0.8000 - val_loss: 0.4187
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7788 - loss: 0.5466 - val_accuracy: 0.8444 - val_loss: 0.3930
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8094 - loss: 0.4434 - val_accuracy: 0.8444 - val_loss: 0.3721
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7899 - loss: 0.4457 - val_accuracy: 0.8444 - val_loss: 0.3534
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - class_output_accuracy: 0.2514 - class_output_loss: 1.1092 - loss: 17.1939 - reg_output_loss: 16.0996 - reg_output_mae: 3.5927 - val_class_output_accuracy: 0.1778 - val_class_output_loss: 1.0586 - val_loss: 13.2943 - val_reg_output_loss: 12.1547 - val_reg_output_mae: 2.8863
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - class_output_accuracy: 0.3659 - class_output_loss: 1.0637 - loss: 13.3550 - reg_output_loss: 12.3189 - reg_output_mae: 2.9496 - val_class_output_accuracy: 0.5778 - val_class_output_loss: 0.9788 - val_loss: 11.0061 - val_reg_output_loss: 9.9990 - val_reg_output_mae: 2.4905
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - class_output_accuracy: 0.4694 - class_output_loss: 1.0000 - loss: 12.2050 - reg_output_loss: 11.2041 - reg_output_mae: 2.8240 - val_class_output_accuracy: 0.6889 - val_class_output_loss: 0.9042 - val_loss: 8.5798 - val_reg_output_loss: 7.7021 - val_reg_output_mae: 2.2167
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - class_output_accuracy: 0